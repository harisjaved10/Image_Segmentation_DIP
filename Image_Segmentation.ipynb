# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Using K Method for Image Segmentation

# %%
original_image = cv2.imread("Image1.jpg")
original_image = cv2.resize(original_image, (300,300))

img = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB) # To add RGB Component

vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized) # K-Means Method of OpenCV

# As there are basically three colours in the image that is Orange, White and Green. So I will take k=3.
K=3

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0) # Stop algorithm if accuracy is reached or iterations are fullfilled
attempts=20

ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS) # To take initial centers

center = np.uint8(center) 

res = center[label.flatten()]
result_image = res.reshape((img.shape)) # Accessing labels to regenerate cluster image

#Plot images

plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image) 
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()

# %%
original_image = cv2.imread("Image2.jpg")
original_image = cv2.resize(original_image, (300,300))

img = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB) # To add RGB Component

vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized) # K-Means Method of OpenCV

# There are 5 colours in the image, so value of k will be 5
K=5

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0) # Stop algorithm if accuracy is reached or iterations are fullfilled
attempts=20

ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS) # To take initial centers

center = np.uint8(center) 

res = center[label.flatten()]
result_image = res.reshape((img.shape)) # Accessing labels to regenerate cluster image

#Plot images

plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image) 
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()

# %%
original_image = cv2.imread("Image3.jpg")
original_image = cv2.resize(original_image, (300,300))

img = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB) # To add RGB Component

vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized) # K-Means Method of OpenCV

# There are 7 colours in the image, so value of k will be 7
K=7

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0) # Stop algorithm if accuracy is reached or iterations are fullfilled
attempts=20

ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS) # To take initial centers

center = np.uint8(center) 

res = center[label.flatten()]
result_image = res.reshape((img.shape)) # Accessing labels to regenerate cluster image

#Plot images

plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image) 
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()

# %%
original_image = cv2.imread("Image4.jpg")
original_image = cv2.resize(original_image, (300,300))

img = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB) # To add RGB Component

vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized) # K-Means Method of OpenCV

# There are multiple colours in the image, so lets set value of k to 10
K=10

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0) # Stop algorithm if accuracy is reached or iterations are fullfilled
attempts=20

ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS) # To take initial centers

center = np.uint8(center) 

res = center[label.flatten()]
result_image = res.reshape((img.shape)) # Accessing labels to regenerate cluster image

#Plot images

plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image) 
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()

# %%
original_image = cv2.imread("Image5.jpg")
original_image = cv2.resize(original_image, (300,300))

img = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB) # To add RGB Component

vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized) # K-Means Method of OpenCV

# There are approx 6 colours in the image, so lets set value of k to 6
K=6

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0) # Stop algorithm if accuracy is reached or iterations are fullfilled
attempts=20

ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS) # To take initial centers

center = np.uint8(center) 

res = center[label.flatten()]
result_image = res.reshape((img.shape)) # Accessing labels to regenerate cluster image

#Plot images

plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image) 
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()

# %%
original_image = cv2.imread("Image6.jpg")
original_image = cv2.resize(original_image, (300,300))

img = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB) # To add RGB Component

vectorized = img.reshape((-1,3))
vectorized = np.float32(vectorized) # K-Means Method of OpenCV

# There are multiple colours in the image, so lets set value of k to 12
K=12

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0) # Stop algorithm if accuracy is reached or iterations are fullfilled
attempts=20

ret,label,center=cv2.kmeans(vectorized,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS) # To take initial centers

center = np.uint8(center) 

res = center[label.flatten()]
result_image = res.reshape((img.shape)) # Accessing labels to regenerate cluster image

#Plot images

plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(result_image) 
plt.title('Segmented Image when K = %i' % K), plt.xticks([]), plt.yticks([])
plt.show()
